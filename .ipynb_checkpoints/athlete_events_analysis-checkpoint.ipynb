# %%
import pandas as pd
event_detail = pd.read_csv('/Users/E1323736/Personal/sportsStats/sportsStats/athlete_events.csv/athlete_events.csv')

event_detail['Year'] = pd.to_numeric(event_detail['Year'])

event_detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 20.7+ MB

# %%
pd.set_option('display.max_colwidth',None)
event_detail.head(25)
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %%
##Initial Exploratory of athelete events

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())
pysqldf('SELECT * FROM event_detail;').head(50)
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10   6                     Per Knut Aaland   M  31.0   188.0    75.0
# 11   6                     Per Knut Aaland   M  31.0   188.0    75.0
# 12   6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
attendees_detail = pd.DataFrame(pysqldf("SELECT COUNT(Name) AS Attendees,Sex, AVG(Height) AS Average_height,AVG(Weight) as Average_weight,Sport,Team FROM event_detail WHERE (Height<>'' AND Weight <> '')GROUP BY Sport,Team,Sex ORDER BY Attendees DESC"))
display(attendees_detail)
# Out:
#       Attendees Sex  Average_height  Average_weight      Sport           Team
# 0          2135   M      181.945199       77.066979  Athletics  United States
# 1          1031   M      181.344326       74.704171  Athletics  Great Britain
# 2           842   F      170.374109       61.963183  Athletics  United States
# 3           805   M      179.381366       72.562733  Athletics         France
# 4           733   M      182.357435       77.446112  Athletics        Germany
# ...         ...  ..             ...             ...        ...            ...
# 6666          1   F      167.000000       69.000000  Wrestling         Norway
# 6667          1   F      163.000000       58.000000  Wrestling           Peru
# 6668          1   F      155.000000       55.000000  Wrestling    Puerto Rico
# 6669          1   M      160.000000       56.000000  Wrestling     San Marino
# 6670          1   M      156.000000       52.000000  Wrestling      Sri Lanka
#
# [6671 rows x 6 columns]

# %%
sports_distribution_by_region = pd.DataFrame(pysqldf("SELECT COUNT(CASE Sex WHEN 'M' THEN 1 ELSE NULL END) AS Male_Attendees, COUNT(CASE Sex WHEN 'F' THEN 1 ELSE NULL END) AS Female_Attendees, Sport,Team FROM event_detail GROUP BY Sport, Team ORDER BY Male_Attendees DESC, Female_Attendees DESC"))
display(sports_distribution_by_region)
# Out:
#       Male_Attendees  Female_Attendees       Sport                      Team
# 0               2348               854   Athletics             United States
# 1               1615               625   Athletics             Great Britain
# 2               1367               572  Gymnastics             United States
# 3               1140               354   Athletics                    France
# 4               1126               450  Gymnastics                    France
# ...              ...               ...         ...                       ...
# 5197               0                 1     Archery                    Jordan
# 5198               0                 1     Archery                      Iraq
# 5199               0                 1     Archery        Dominican Republic
# 5200               0                 1     Archery  Central African Republic
# 5201               0                 1     Archery                Azerbaijan
#
# [5202 rows x 4 columns]

# %%
medal_standings_by_region = pd.DataFrame(pysqldf("SELECT COUNT(Name) AS Attendees,COUNT(Medal) AS Medal,COUNT(CASE Medal WHEN 'Gold' THEN 1 ELSE NULL END) AS Gold,COUNT(CASE Medal WHEN 'Silver' THEN 1 ELSE NULL END) AS Silver, COUNT(CASE Medal WHEN 'Bronze' THEN 1 ELSE NULL END) AS Bronze, Team, Year FROM event_detail WHERE Year = 2016 GROUP BY Team, Year ORDER BY Attendees Desc"))
display(medal_standings_by_region)
# Out:
#      Attendees  Medal  Gold  Silver  Bronze               Team  Year
# 0          699    256   137      52      67      United States  2016
# 1          571     46    34       6       6             Brazil  2016
# 2          528    157    47      43      67            Germany  2016
# 3          510     82    23      34      25          Australia  2016
# 4          504     96    20      55      21             France  2016
# ..         ...    ...   ...     ...     ...                ...   ...
# 244          2      0     0       0       0      Switzerland-2  2016
# 245          2      0     0       0       0          Ukraine-1  2016
# 246          2      0     0       0       0          Ukraine-2  2016
# 247          1      0     0       0       0  Equatorial Guinea  2016
# 248          1      0     0       0       0             Tuvalu  2016
#
# [249 rows x 7 columns]

# %%
competitiveness = pd.DataFrame(pysqldf("SELECT COUNT(Medal)*1.0/COUNT(Name) as Percentage, COUNT(Name) As Attendees,COUNT(Medal) As Medal, COUNT(CASE Medal WHEN 'Gold' THEN 1 ELSE NULL END) AS Gold, Team, Sport, Year FROM event_detail WHERE Year = 2016 GROUP BY Sport, Team, Year ORDER BY Attendees DESC, Percentage DESC"))
display(competitiveness)
# Out:
#       Percentage  Attendees  Medal  Gold           Team      Sport  Year
# 0       0.315068        146     46    27  United States  Athletics  2016
# 1       0.717172         99     71    48  United States   Swimming  2016
# 2       0.032258         93      3     2        Germany  Athletics  2016
# 3       0.162791         86     14     2  Great Britain  Athletics  2016
# 4       0.385542         83     32     7      Australia   Swimming  2016
# ...          ...        ...    ...   ...            ...        ...   ...
# 1928    0.000000          1      0     0    Netherlands  Wrestling  2016
# 1929    0.000000          1      0     0          Palau  Wrestling  2016
# 1930    0.000000          1      0     0           Peru  Wrestling  2016
# 1931    0.000000          1      0     0          Spain  Wrestling  2016
# 1932    0.000000          1      0     0        Vietnam  Wrestling  2016
#
# [1933 rows x 7 columns]

# %%
sports_popularity_by_season = pd.DataFrame(pysqldf("SELECT COUNT(Name) AS Attendees, Sport, Season FROM event_detail GROUP BY Sport, Season ORDER BY Attendees DESC"))

# %%
def descriptive_stats(table_name, table_col):
    print("************************************************")
    print(f"Table Name: {table_name}")
    print(f"Table Col: {table_col}")
    print("************************************************")
    
    print("")
    
    #count
    cnt = pysqldf(f"""SELECT "COUNT" as Stat, count({table_col}) as Value
                      FROM  {table_name}; """)
    #mean
    mean = pysqldf(f"""SELECT "MEDIAN" as Stat, {table_col} as Value 
                      FROM {table_name} 
                      ORDER BY {table_col}
                      LIMIT 1
                      OFFSET (SELECT COUNT(*) FROM {table_name})/2
                      """)
    #mode
    mode = pysqldf(f"""SELECT 'MODE' as Stat,
                        {table_col} as Value,
                        COUNT(*) as Count
                        FROM {table_name}
                        GROUP BY {table_col}
                        ORDER BY COUNT(*) DESC
                        LIMIT 1
                        """)
    #min and max
    min = pysqldf(f"""SELECT 'MIN' as Stat, MIN({table_col}) as Value
                             FROM {table_name}""")
    max = pysqldf(f"""SELECT 'MAX' as Stat, MAX({table_col}) as Value
                             FROM {table_name}""")
    display(pd.concat([cnt, mean, mode, min, max]).set_index("Stat"))
    display(mode.set_index('Stat'))
    print("")

# %%
#For 25-50-75-100 quartile range in SQL

def get_iqrs(table_name, table_col):
    query = f"""WITH percent_tbl as (
    SELECT {table_col},
    ntile(4) OVER(
    ORDER BY {table_col})
    percent
    FROM {table_name}),
    p_25 as (SELECT (percent * 0.25) as pct,
         last_value({table_col})
         over (partition by percent) last_val
         from percent_tbl
         where percent = 1 limit 1),
    p_50 as (SELECT (percent * 0.25) as pct,
         last_value({table_col})
         over (partition by percent) last_val
         from percent_tbl
         where percent = 2 limit 1),
    p_75 as (SELECT (percent * 0.25) as pct,
         last_value({table_col})
         over (partition by percent) last_val
         from percent_tbl
         where percent = 3 limit 1),
    p_100 as (SELECT (percent * 0.25) as pct,
         last_value({table_col})
         over (partition by percent) last_val
         from percent_tbl
         where percent = 4 limit 1)
    SELECT * FROM p_25 UNION
    SELECT * FROM p_50 UNION
    SELECT * FROM p_75 UNION
    SELECT * FROM p_100; """
    iqrs = pysqldf(query)
    return display(pd.DataFrame(iqrs))

# %%
for col in event_detail.columns:
    descriptive_stats('event_detail', col)
    get_iqrs('event_detail', col)
# Out:
# ************************************************
# Table Name: event_detail
# Table Col: ID
# ************************************************
#          Value  Count
# Stat
# COUNT   271116    NaN
# MEDIAN   68205    NaN
# MODE     77710   58.0
# MIN          1    NaN
# MAX     135571    NaN
#       Value  Count
# Stat
# MODE  77710     58
#     pct  last_val
# 0  0.25     34643
# 1  0.50     68205
# 2  0.75    102097
# 3  1.00    135571
# ************************************************
# Table Name: event_detail
# Table Col: Name
# ************************************************
#                                             Value  Count
# Stat
# COUNT                                      271116    NaN
# MEDIAN              Katarzyna Gbala (-Roszkowska)    NaN
# MODE                         Robert Tait McKenzie   58.0
# MIN       Gabrielle Marie "Gabby" Adcock (White-)    NaN
# MAX                                      zzet nce    NaN
#                      Value  Count
# Stat
# ...

# %%
pd.set_option('display.float_format', lambda x: '%2f' % x)

# %%
display(event_detail.describe())
event_participants_by_year = pd.DataFrame(pysqldf("SELECT COUNT(*) as cnt, Year as year FROM event_detail GROUP BY year ORDER BY year DESC"))
# Out:
#                  ID           Age        Height        Weight          Year
# count 271116.000000 261642.000000 210945.000000 208241.000000 271116.000000
# mean   68248.954396     25.556898    175.338970     70.702393   1978.378480
# std    39022.286345      6.393561     10.518462     14.348020     29.877632
# min        1.000000     10.000000    127.000000     25.000000   1896.000000
# 25%    34643.000000     21.000000    168.000000     60.000000   1960.000000
# 50%    68205.000000     24.000000    175.000000     70.000000   1988.000000
# 75%   102097.250000     28.000000    183.000000     79.000000   2002.000000
# max   135571.000000     97.000000    226.000000    214.000000   2016.000000

# %%
#Visualization
import matplotlib.pyplot as plt 

plt.style.use('fivethirtyeight')

# %%
event_detail.Year.hist()
# Out:
# <AxesSubplot:>

# %%
event_participants_by_year.plot("year", "cnt")
plt.title("Count of athletic attendees by Year", fontname = 'DejaVu Sans', fontsize = 14, fontstyle='italic', fontweight='bold')
plt.show()

# %%
medal_standings_by_region.to_csv("medal_standings_by_region.csv")

# %%
attendees_detail.to_csv("attendees_detail.csv")

# %%
sports_distribution_by_region.to_csv("sports_distribution_by_region.csv")

# %%
competitiveness.to_csv("competitiveness.csv")

# %%
sports_popularity_by_season.to_csv("sports_popularity_by_season.csv")
