# %%
import pandas as pd
event_detail = pd.read_csv('/Users/E1323736/Personal/sportsStats/sportsStats/athlete_events.csv/athlete_events.csv')

event_detail['Year'] = pd.to_numeric(event_detail['Year'])

event_detail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 20.7+ MB

# %%
pd.set_option('display.max_colwidth',None)
event_detail.head(25)
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0    80.0           China
# 1    2                  A Lamusi   M  23.0   170.0    60.0           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0   United States
# ...

# %%
import matplotlib
event_detail.Year.hist()
# Out:
# <AxesSubplot:>

# %%
##Initial Exploratory of athelete events

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())
pysqldf('SELECT * FROM event_detail;').head(50)
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7    5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9    5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10   6                     Per Knut Aaland   M  31.0   188.0    75.0
# 11   6                     Per Knut Aaland   M  31.0   188.0    75.0
# 12   6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
pysqldf("SELECT COUNT(Name) AS Attendees,Sex, AVG(Height) AS Average_height,AVG(Weight) as Average_weight,Sport,Team FROM event_detail WHERE (Height<>'' AND Weight <> '')GROUP BY Sport,Team,Sex ORDER BY Attendees DESC").head(100)
# Out:
#     Attendees Sex  Average_height  Average_weight                 Sport  \
# 0        2135   M      181.945199       77.066979             Athletics
# 1        1031   M      181.344326       74.704171             Athletics
# 2         842   F      170.374109       61.963183             Athletics
# 3         805   M      179.381366       72.562733             Athletics
# 4         733   M      182.357435       77.446112             Athletics
# ..        ...  ..             ...             ...                   ...
# 95        268   M      189.376866       85.033582                Rowing
# 96        266   F      171.135338       58.913534              Swimming
# 97        266   M      185.823308       79.240602              Swimming
# 98        265   M      181.558491       77.883019             Athletics
# 99        264   M      180.852273       73.893939  Cross Country Skiing
#
#              Team
# 0   United States
# 1   Great Britain
# 2   United States
# 3          France
# ...

# %%
pysqldf("SELECT COUNT(Name) AS Attendees, Sex, Sport,Team FROM event_detail GROUP BY Sport,Sex,Team ORDER BY Attendees DESC")
# Out:
#       Attendees Sex       Sport           Team
# 0          2348   M   Athletics  United States
# 1          1615   M   Athletics  Great Britain
# 2          1367   M  Gymnastics  United States
# 3          1140   M   Athletics         France
# 4          1126   M  Gymnastics         France
# ...         ...  ..         ...            ...
# 7734          1   M   Wrestling       Honduras
# 7735          1   M   Wrestling      Nicaragua
# 7736          1   M   Wrestling     San Marino
# 7737          1   M   Wrestling      Sri Lanka
# 7738          1   M   Wrestling          Yemen
#
# [7739 rows x 4 columns]

# %%
pysqldf("SELECT COUNT(Name) AS Attendees,Sex,Sport FROM event_detail GROUP BY Sport, Sex ORDER BY Attendees DESC")
# Out:
#      Attendees Sex          Sport
# 0        26958   M      Athletics
# 1        17578   M     Gymnastics
# 2        13345   M       Swimming
# 3        11666   F      Athletics
# 4         9850   F       Swimming
# ..         ...  ..            ...
# 111          4   M          Roque
# 112          2   M  Basque Pelota
# 113          1   M    Aeronautics
# 114          1   F       Alpinism
# 115          1   F   Motorboating
#
# [116 rows x 3 columns]

# %%
pysqldf("SELECT COUNT(Name) AS Attendees,COUNT(Medal) AS Medal,COUNT(CASE Medal WHEN 'Gold' THEN 1 ELSE NULL END) AS Gold,COUNT(CASE Medal WHEN 'Silver' THEN 1 ELSE NULL END) AS Silver, COUNT(CASE Medal WHEN 'Bronze' THEN 1 ELSE NULL END) AS Bronze, Team, Year FROM event_detail WHERE Year = 2016 GROUP BY Team, Year ORDER BY Attendees Desc").head(25)
# Out:
#     Attendees  Medal  Gold  Silver  Bronze           Team  Year
# 0         699    256   137      52      67  United States  2016
# 1         571     46    34       6       6         Brazil  2016
# 2         528    157    47      43      67        Germany  2016
# 3         510     82    23      34      25      Australia  2016
# 4         504     96    20      55      21         France  2016
# 5         483    109    44      30      35          China  2016
# 6         470    145    64      55      26  Great Britain  2016
# 7         436     64    17      13      34          Japan  2016
# 8         398    113    50      28      35         Russia  2016
# 9         397     69     4       4      61         Canada  2016
# 10        395     70     8      38      24          Italy  2016
# 11        353     43     7      19      17          Spain  2016
# 12        321     45     9      25      11    Netherlands  2016
# 13        285     16     3       3      10         Poland  2016
# ...

# %%
pysqldf("SELECT COUNT(Medal)*1.0/COUNT(Name) as Percentage, COUNT(Name) As Attendees,COUNT(Medal) As Medal, COUNT(CASE Medal WHEN 'Gold' THEN 1 ELSE NULL END) AS Gold, Team, Sport, Year FROM event_detail WHERE Year = 2016 GROUP BY Sport, Team, Year ORDER BY Attendees DESC, Percentage DESC")
# Out:
#       Percentage  Attendees  Medal  Gold           Team      Sport  Year
# 0       0.315068        146     46    27  United States  Athletics  2016
# 1       0.717172         99     71    48  United States   Swimming  2016
# 2       0.032258         93      3     2        Germany  Athletics  2016
# 3       0.162791         86     14     2  Great Britain  Athletics  2016
# 4       0.385542         83     32     7      Australia   Swimming  2016
# ...          ...        ...    ...   ...            ...        ...   ...
# 1928    0.000000          1      0     0    Netherlands  Wrestling  2016
# 1929    0.000000          1      0     0          Palau  Wrestling  2016
# 1930    0.000000          1      0     0           Peru  Wrestling  2016
# 1931    0.000000          1      0     0          Spain  Wrestling  2016
# 1932    0.000000          1      0     0        Vietnam  Wrestling  2016
#
# [1933 rows x 7 columns]

# %%
pysqldf("SELECT COUNT(Name) AS Attendees, Sport, Season FROM event_detail GROUP BY Sport, Season ORDER BY Attendees DESC")
# Out:
#     Attendees          Sport  Season
# 0       38624      Athletics  Summer
# 1       26707     Gymnastics  Summer
# 2       23195       Swimming  Summer
# 3       11448       Shooting  Summer
# 4       10859        Cycling  Summer
# ..        ...            ...     ...
# 64         11   Jeu De Paume  Summer
# 65          4       Alpinism  Summer
# 66          4          Roque  Summer
# 67          2  Basque Pelota  Summer
# 68          1    Aeronautics  Summer
#
# [69 rows x 3 columns]
